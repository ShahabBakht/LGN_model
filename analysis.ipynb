# %%
import numpy as np

LGN_resp = np.load('LGN_allen_movie_one.npy')
print(LGN_resp.shape)
# Out:
# (1, 20, 30, 304, 608)

# %%
import matplotlib.pyplot as plt

plt.plot(LGN_resp[0,0,:,100,100])
plt.show()

plt.imshow(LGN_resp[0,18,25,:,:])
plt.show()
